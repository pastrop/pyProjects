# %%
import requests
from pprint import pprint
from bs4 import BeautifulSoup

# %%
req=requests.get('https://api.orb-intelligence.com/3/search/?api_key=c66c5dad-395c-4ec6-afdf-7b78eb94166a&limit=5&entity_type=company&city=Long%20Island%20City&state=NY&country=United%20States&employees=1-10&sic_codes=5812')
pprint(req.json())
# Out:
# {'results': [{'address1': '27-18 QUEENS PLZ S',
#               'branches_count': 0,
#               'city': 'LONG ISLAND CITY',
#               'company_status': 'active',
#               'country': 'United States',
#               'entity_type': 'company',
#               'fetch_url': 'http://api.orb-intelligence.com/3/fetch/37322829/?api_key=c66c5dad-395c-4ec6-afdf-7b78eb94166a',
#               'is_standalone_company': True,
#               'iso_country_code': 'US',
#               'name': 'Raj’s Indian Kitchen',
#               'orb_num': 37322829,
#               'parent_name': None,
#               'parent_orb_num': None,
#               'state': 'NY',
#               'subsidiaries_count': 0,
#               'ultimate_parent_name': None,
#               'ultimate_parent_orb_num': None,
#               'zip': '11101'},
#              {'address1': '35-60 11TH ST',
#               'branches_count': 0,
#               'city': 'LONG ISLAND CITY',
# ...

# %%
payload = {'api_key': 'c66c5dad-395c-4ec6-afdf-7b78eb94166a', 
           'limit': 5,
          'entity_type': 'company',
          'city': 'Long Island City',
          'state': 'NY',
          'country':'United States',
          'employees':'1-10',
          'sic_codes': 5812}

req=requests.get('https://api.orb-intelligence.com/3/search/', params=payload)
pprint(req.json())
# Out:
# {'results': [{'address1': '27-18 QUEENS PLZ S',
#               'branches_count': 0,
#               'city': 'LONG ISLAND CITY',
#               'company_status': 'active',
#               'country': 'United States',
#               'entity_type': 'company',
#               'fetch_url': 'http://api.orb-intelligence.com/3/fetch/37322829/?api_key=c66c5dad-395c-4ec6-afdf-7b78eb94166a',
#               'is_standalone_company': True,
#               'iso_country_code': 'US',
#               'name': 'Raj’s Indian Kitchen',
#               'orb_num': 37322829,
#               'parent_name': None,
#               'parent_orb_num': None,
#               'state': 'NY',
#               'subsidiaries_count': 0,
#               'ultimate_parent_name': None,
#               'ultimate_parent_orb_num': None,
#               'zip': '11101'},
#              {'address1': '35-60 11TH ST',
#               'branches_count': 0,
#               'city': 'LONG ISLAND CITY',
# ...
